# %% [markdown]
# # 03: Songs Database (Placeholder Notebook)
#
# ### ⚠️ Database Missing Notice
#
# The `songs.csv` and `songs.db` files are not present in the original CS50 repository for this project.
#
# To keep the workspace organized and properly cataloged, this notebook acts as a placeholder documentation page explaining how songs database schemas are typically designed.
#
# ### Typcial CS50 Songs Database Design
#
# In the CS50 SQL suite, the `songs.db` database typically consists of the following two relational tables:
#
# 1. **`artists`**:
#    - `id`: INTEGER (Primary Key)
#    - `name`: TEXT (Name of the artist/band)
#
# 2. **`songs`**:
#    - `id`: INTEGER (Primary Key)
#    - `name`: TEXT (Name of the song)
#    - `artist_id`: INTEGER (Foreign Key referencing `artists.id`)
#    - `danceability`: REAL
#    - `energy`: REAL
#    - `key`: INTEGER
#    - `loudness`: REAL
#    - `speechiness`: REAL
#    - `valence`: REAL
#    - `tempo`: REAL
#    - `duration_ms`: INTEGER
#
# ### Example SQL Commands Executed on Songs Database
#
# If the database were present, queries like the following could be run:
#
# ```sql
# -- Find all songs by Post Malone
# SELECT name FROM songs
# WHERE artist_id = (
#     SELECT id FROM artists
#     WHERE name = 'Post Malone'
# );
#
# -- Find the average energy of all songs
# SELECT AVG(energy) FROM songs;
# ```
